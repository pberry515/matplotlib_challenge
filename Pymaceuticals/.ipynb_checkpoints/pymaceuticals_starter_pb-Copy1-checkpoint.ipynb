# %% [markdown]
# ## Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset

combined_data_df = mouse_metadata.merge(study_results, how='left', on='Mouse ID', sort = False)

# Display the data table for preview

combined_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.

total_mice = combined_data_df['Mouse ID'].count()
total_mice
# Out:
# 1893

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 

duplicate_mice = combined_data_df.loc[combined_data_df.duplicated(subset=['Mouse ID', 'Timepoint'])]
duplicate_mice
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 909     g989     Propriva  Female          21          26          0
# 911     g989     Propriva  Female          21          26          5
# 913     g989     Propriva  Female          21          26         10
# 915     g989     Propriva  Female          21          26         15
# 917     g989     Propriva  Female          21          26         20
#
#      Tumor Volume (mm3)  Metastatic Sites
# 909           45.000000                 0
# 911           47.570392                 0
# 913           49.880528                 0
# 915           53.442020                 0
# 917           54.657650                 1

# %%
# Optional: Get all the data for the duplicate mouse ID. # difference between original and unique is 249, next
# step should create a df of 249

all_duplicate_mice = combined_data_df[combined_data_df.duplicated(['Mouse ID'])]
all_duplicate_mice
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# 5        k403     Ramicane  Male          21          16         25
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 1              38.825898                 0
# 2              35.014271                 1
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.

clean_data_df=combined_data_df[combined_data_df['Mouse ID'].isin(duplicate_mice)==False]
clean_data_df
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.

cleaned_mice = clean_data_df['Mouse ID'].count()
cleaned_mice
# Out:
# 1893

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each 
# regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary dataframe.

#Creating the variables

mean = clean_data_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].mean()
median = clean_data_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].median()
variance = clean_data_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].var()
standard_deviation = clean_data_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].std()
sem = clean_data_df.groupby('Drug Regimen')["Tumor Volume (mm3)"].sem()

#Creating the dataframe
summary_table_df = pd.DataFrame({'Mean': mean,
                                'Median':median,
                                'Variance': variance,
                                'Std Dev': standard_deviation,
                                'SEM': sem})
summary_table_df
# Out:
#                    Mean     Median   Variance   Std Dev       SEM
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Using the aggregation method, produce the same summary statistics in a single line

single_group_by = clean_data_df.groupby('Drug Regimen')

summary_stats = single_group_by.agg(['mean','median','var','std','sem'])["Tumor Volume (mm3)"]

summary_stats
# Out:
#                    mean     median        var       std       sem
# Drug Regimen
# Capomulin     40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin      52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol     52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril      55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol      54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo       54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva      52.322552  50.854632  42.351070  6.507770  0.512884
# Ramicane      40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn      54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol     53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pandas.

mice_per_treatment=clean_data_df.groupby(['Drug Regimen']).count()['Mouse ID']
plot_pd = mice_per_treatment.plot.bar(figsize=(15,10), color='b',fontsize=12)

mice_per_treatment

#Formatting

plt.xlabel('Drug Regimen',fontsize = 16)
plt.ylabel("Total Number of Mice", fontsize=16)
plt.title("Total Mice per Treatment", fontsize=20)

plt.savefig('Images/Mice_per_treatment_bar.png',bbox_inches='tight')

plt.tight_layout
plt.show()
            
mice_per_treatment
# Out:
# Drug Regimen
# Capomulin    230
# Ceftamin     178
# Infubinol    178
# Ketapril     188
# Naftisol     186
# Placebo      181
# Propriva     161
# Ramicane     228
# Stelasyn     181
# Zoniferol    182
# Name: Mouse ID, dtype: int64

# %%
# Generate a bar plot showing the total number of measurements taken on each drug regimen using pyplot.
# Need to Create an array for the number of mice in each of the regimens

#Creating the drug list

total_drug_list=mice_per_treatment.index.tolist()

total_drug_list
# Out:
# ['Capomulin',
#  'Ceftamin',
#  'Infubinol',
#  'Ketapril',
#  'Naftisol',
#  'Placebo',
#  'Propriva',
#  'Ramicane',
#  'Stelasyn',
#  'Zoniferol']

# %%
#creating the drug count

total_drug_count = (clean_data_df.groupby(['Drug Regimen'])['Mouse ID'].count()).tolist()

total_drug_count
# Out:
# [230, 178, 178, 188, 186, 181, 161, 228, 181, 182]

# %%
#Setting up the x_axis
x_axis = np.arange(len(total_drug_count))

# %%
#Creating the x_axis

x_axis = total_drug_list

#Customizing and creating the bar chart

plt.figure(figsize=(15,10))
plt.bar(x_axis, total_drug_count,color='g', alpha=0.5,align='center')

plt.title("Total Drug Treatment Count",fontsize=20)
plt.xlabel("Drug Regimen",fontsize=16)
plt.ylabel("Total Count",fontsize=16)

plt.savefig('Drug_treatment_count.png', bbox_inches='tight')

# %%
#Creating gender dataframe

gender_df=pd.DataFrame(clean_data_df.groupby(['Sex']).count()).reset_index()
gender_df
# Out:
#       Sex  Mouse ID  Drug Regimen  Age_months  Weight (g)  Timepoint  \
# 0  Female       935           935         935         935        935
# 1    Male       958           958         958         958        958
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0                 935               935
# 1                 958               958

# %%
#Choose Column to create values for pie chart

gender_df=gender_df[['Sex', 'Age_months']]

gender_df
# Out:
#       Sex  Age_months
# 0  Female         935
# 1    Male         958

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas

plt.figure(figsize=(12,12))

ax1 = plt.subplot(121,aspect='equal')
gender_df.plot(kind="pie",y="Age_months", ax=ax1, autopct='%1.1f%%',startangle=190,shadow=True, labels=gender_df["Sex"],
               legend=False,fontsize=16)
plt.title("Gender Percentage")
plt.xlabel("")
plt.ylabel("")

plt.savefig('gender_count.png', bbox_inches='tight')

# %%
#Create data to plot

gender_count = (clean_data_df.groupby(['Sex'])['Age_months'].count()).tolist()
gender_count
# Out:
# [935, 958]

# %%
# Adding labels

labels=["Females","Males"]
colors=['blue','green']
explode =(0.1,0)
# Generate a pie plot showing the distribution of female versus male mice using pyplot

plt.pie(gender_count,explode=explode, labels=labels, colors=colors, autopct='%1.1f%%',shadow=True,startangle=160)
plt.axis('equal')

plt.savefig('gender_count_new.png')

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

regimen = clean_data_df[clean_data_df["Drug Regimen"].isin(["Capomulin", "Ramicane", "Infubinol", "Ceftamin"])]
regimen = regimen.sort_values(["Timepoint"], ascending=True)
regimen
# Out:
#      Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane    Male          21          16          0
# 1391     q132    Infubinol  Female           1          30          0
# 195      i738    Capomulin  Female          23          20          0
# 205      a520     Ramicane    Male          13          21          0
# 1370     p438     Ceftamin  Female          11          26          0
# ...       ...          ...     ...         ...         ...        ...
# 350      v923    Capomulin  Female          19          21         45
# 144      m957    Capomulin  Female           3          19         45
# 337      j119    Capomulin  Female           7          23         45
# 59       s508     Ramicane    Male           1          17         45
# 1872     z581    Infubinol  Female          24          25         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# ...

# %%
#Creating the new data

regimen_data = regimen[["Drug Regimen", "Mouse ID", "Timepoint", "Tumor Volume (mm3)"]]

regimen_data
# Out:
#      Drug Regimen Mouse ID  Timepoint  Tumor Volume (mm3)
# 0        Ramicane     k403          0           45.000000
# 1391    Infubinol     q132          0           45.000000
# 195     Capomulin     i738          0           45.000000
# 205      Ramicane     a520          0           45.000000
# 1370     Ceftamin     p438          0           45.000000
# ...           ...      ...        ...                 ...
# 350     Capomulin     v923         45           40.658124
# 144     Capomulin     m957         45           33.329098
# 337     Capomulin     j119         45           38.125164
# 59       Ramicane     s508         45           30.276232
# 1872    Infubinol     z581         45           62.754451
#
# [814 rows x 4 columns]

# %%
#generating bodx plot final tumor volume for each mouse across the four regimens

#Group by Drug Regimen and Mouse ID

regimen_sort = regimen_data.groupby(['Drug Regimen', 'Mouse ID']).last()['Tumor Volume (mm3)']
regimen_sort.head()
# Out:
# Drug Regimen  Mouse ID
# Capomulin     b128        38.982878
#               b742        38.939633
#               f966        30.485985
#               g288        37.074024
#               g316        40.159220
# Name: Tumor Volume (mm3), dtype: float64

# %%
#Create a dataframe for the retrieved data

regimen_df = regimen_sort.to_frame()
regimen_df
# Out:
#                        Tumor Volume (mm3)
# Drug Regimen Mouse ID
# Capomulin    b128               38.982878
#              b742               38.939633
#              f966               30.485985
#              g288               37.074024
#              g316               40.159220
# ...                                   ...
# Ramicane     s508               30.276232
#              u196               40.667713
#              w678               43.166373
#              y449               44.183451
#              z578               30.638696
#
# [100 rows x 1 columns]

# %%
# Create a data label list

top_drug = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# %%
# Create boxplot with final tumor volume four the four drugs

final_df = regimen_df.reset_index()
tumor_lists = final_df.groupby('Drug Regimen')['Tumor Volume (mm3)'].apply(list)
tumor_list_df = pd.DataFrame(tumor_lists)
tumor_list_df = tumor_list_df.reindex(top_drug)
tumor_vols = [vol for vol in tumor_list_df['Tumor Volume (mm3)']]
plt.boxplot(tumor_vols, labels=top_drug)
plt.ylim(10, 80)
plt.show()

plt.savefig('boxplot.png')

# %%
# Put treatments into a list for for loop (and later for plot labels)


# Create empty list to fill with tumor vol data (for plotting)


# Calculate the IQR and quantitatively determine if there are any potential outliers. 

    
    # Locate the rows which contain mice on each drug and get the tumor volumes
    
    
    # add subset 
    
    
    # Determine outliers using upper and lower bounds

# %%
#Creating data frames for the quartiles

Capomulin_df = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Capomulin",:]
Ramicane_df = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Ramicane", :]
Infubinol_df = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Infubinol", :]
Ceftamin_df = clean_data_df.loc[clean_data_df["Drug Regimen"] == "Ceftamin", :]

# Capomulin
Capomulin_last = Capomulin_df.groupby('Mouse ID').max()['Timepoint']
Capomulin_vol = pd.DataFrame(Capomulin_last)
Capomulin_merge = pd.merge(Capomulin_vol, clean_data_df, on=("Mouse ID","Timepoint"),how="left")
Capomulin_merge.head()
# Out:
#   Mouse ID  Timepoint Drug Regimen     Sex  Age_months  Weight (g)  \
# 0     b128         45    Capomulin  Female           9          22
# 1     b742         45    Capomulin    Male           7          21
# 2     f966         20    Capomulin    Male          16          17
# 3     g288         45    Capomulin    Male           3          19
# 4     g316         45    Capomulin  Female          22          22
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           38.982878                 2
# 1           38.939633                 0
# 2           30.485985                 0
# 3           37.074024                 1
# 4           40.159220                 2

# %%
# Capomulin quartiles and IQR
# Determine outliers using upper and lower bounds
Capomulin_tumors = Capomulin_merge["Tumor Volume (mm3)"]

quartiles =Capomulin_tumors.quantile([.25,.5,.75])
lowerq = quartiles[0.25]
upperq = quartiles[0.75]
iqr = upperq-lowerq


print(f"The lower quartile of Capomulin tumors: {lowerq}")
print(f"The upper quartile of Capomulin tumors: {upperq}")
print(f"The interquartile range of Capomulin tumors: {iqr}")
print(f"The median of Capomulin tumors: {quartiles[0.5]}")

lower_bound = lowerq - (1.5*iqr)
upper_bound = upperq + (1.5*iqr)

print(f"Values below {lower_bound} could be outliers.")
print(f"Values above {upper_bound} could be outliers.")
The lower quartile of Capomulin tumors: 32.37735684
The upper quartile of Capomulin tumors: 40.1592203
The interquartile range of Capomulin tumors: 7.781863460000004
The median of Capomulin tumors: 38.125164399999996 
Values below 20.70456164999999 could be outliers.
Values above 51.83201549 could be outliers.
# Out:
#   File "<ipython-input-63-044df7d74e7d>", line 21
#     The lower quartile of Capomulin tumors: 32.37735684
#         ^
# SyntaxError: invalid syntax

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
#Create a variable for the tumor vs time

tumor_time = clean_data_df[clean_data_df['Mouse ID'].isin(['b128'])]
tumor_time
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 300     b128    Capomulin  Female           9          22          0
# 301     b128    Capomulin  Female           9          22          5
# 302     b128    Capomulin  Female           9          22         10
# 303     b128    Capomulin  Female           9          22         15
# 304     b128    Capomulin  Female           9          22         20
# 305     b128    Capomulin  Female           9          22         25
# 306     b128    Capomulin  Female           9          22         30
# 307     b128    Capomulin  Female           9          22         35
# 308     b128    Capomulin  Female           9          22         40
# 309     b128    Capomulin  Female           9          22         45
#
#      Tumor Volume (mm3)  Metastatic Sites
# 300           45.000000                 0
# 301           45.651331                 0
# 302           43.270852                 0
# ...

# %%
#Create DF for the data

tumor_time_data = tumor_time[['Mouse ID','Timepoint', 'Tumor Volume (mm3)']]
tumor_time_data
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)
# 300     b128          0           45.000000
# 301     b128          5           45.651331
# 302     b128         10           43.270852
# 303     b128         15           43.784893
# 304     b128         20           42.731552
# 305     b128         25           43.262145
# 306     b128         30           40.605335
# 307     b128         35           37.967644
# 308     b128         40           38.379726
# 309     b128         45           38.982878

# %%
#Reset index on dataframe

line_plot_df=tumor_time_data.reset_index()
line_plot_df
# Out:
#    index Mouse ID  Timepoint  Tumor Volume (mm3)
# 0    300     b128          0           45.000000
# 1    301     b128          5           45.651331
# 2    302     b128         10           43.270852
# 3    303     b128         15           43.784893
# 4    304     b128         20           42.731552
# 5    305     b128         25           43.262145
# 6    306     b128         30           40.605335
# 7    307     b128         35           37.967644
# 8    308     b128         40           38.379726
# 9    309     b128         45           38.982878

# %%
#Redoing the DF after the reset of the index

line_plot_final=line_plot_df[['Mouse ID','Timepoint','Tumor Volume (mm3)']]
line_plot_final
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)
# 0     b128          0           45.000000
# 1     b128          5           45.651331
# 2     b128         10           43.270852
# 3     b128         15           43.784893
# 4     b128         20           42.731552
# 5     b128         25           43.262145
# 6     b128         30           40.605335
# 7     b128         35           37.967644
# 8     b128         40           38.379726
# 9     b128         45           38.982878

# %%
#Plot the line

lines=line_plot_final.plot.line()

plt.savefig('line_chart.png')

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
# Create varaible for Capomulin

capomulin_scatter = clean_data_df[clean_data_df['Drug Regimen'].isin(['Capomulin'])]

#Creating a dataframe

capomulin_scatter_df=clean_data_df[['Mouse ID','Weight (g)','Tumor Volume (mm3)']]

#sort the capomulin variable for Weight
capomulin_sorted=capomulin_scatter_df.sort_values(['Weight (g)'],ascending=True)

#Reset index
capomulin_scatter_plot=capomulin_scatter.reset_index()

#Create the mean

capomulin_grouped_weight = capomulin_scatter_df.groupby('Weight (g)')['Tumor Volume (mm3)'].mean()

# Creat the dataframe and reset

capo_grouped_plot=pd.DataFrame(capomulin_grouped_weight).reset_index()

#plot

capomulin_scatter=capo_grouped_plot.plot(kind='scatter', x='Weight (g)', y='Tumor Volume (mm3)', grid=True, figsize=(8,8))

plt.savefig('scatter_chart.png')

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen


#Create the X and Y values
x_values=capo_grouped_plot['Weight (g)']
y_values=capo_grouped_plot['Tumor Volume (mm3)']

#Create the linear regression
(slope,intercept,rvalue,pvalue,stderr)=st.linregress(x_values, y_values)

#finding regression by x values times the slope and intercept
regress_value=x_values*slope + intercept

#Create the line equation

line_eq="y=" + str(round(slope,2)) + "x+" + str(round(intercept,2))

#Plot the scatter
plt.scatter(x_values,y_values)

# Plot the line
plt.plot(x_values,regress_value,"r-")

#Create Color for line
plt.annotate(line_eq,(6,10),fontsize=10,color='red')

#Create title and labels
plt.xlabel("Weight")
plt.ylabel("Tumor Volume")
plt.title("Weight vs. Avg Tumor Volume")

plt.savefig('linear_regression_chart.png')
